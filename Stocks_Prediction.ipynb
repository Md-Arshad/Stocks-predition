# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Arshad/Stocks-predition/blob/master/Stocks_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Quandl
# Out:
# Collecting Quandl
#   Downloading https://files.pythonhosted.org/packages/12/64/6314547cb01fa75697ddba6d6d43a9f1d023c1730ffc6abf3db7a0c89222/Quandl-3.4.8-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from Quandl) (2.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from Quandl) (1.12.0)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.6/dist-packages (from Quandl) (1.16.5)
# Collecting inflection>=0.3.1 (from Quandl)
#   Downloading https://files.pythonhosted.org/packages/d5/35/a6eb45b4e2356fe688b21570864d4aa0d0a880ce387defe9c589112077f8/inflection-0.3.1.tar.gz
# Collecting more-itertools<=5.0.0 (from Quandl)
#   Downloading https://files.pythonhosted.org/packages/a4/a6/42f17d065bda1fac255db13afc94c93dbfb64393eae37c749b4cb0752fc7/more_itertools-5.0.0-py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 4.6MB/s
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.6/dist-packages (from Quandl) (2.21.0)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.6/dist-packages (from Quandl) (0.24.2)
# Collecting pyOpenSSL (from Quandl)
#   Downloading https://files.pythonhosted.org/packages/01/c8/ceb170d81bd3941cbeb9940fc6cc2ef2ca4288d0ca8929ea4db5905d904d/pyOpenSSL-19.0.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 12.1MB/s
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.6/dist-packages (from Quandl) (0.4.6)
# Collecting ndg-httpsclient (from Quandl)
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->Quandl) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->Quandl) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->Quandl) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->Quandl) (1.24.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14->Quandl) (2018.9)
# Collecting cryptography>=2.3 (from pyOpenSSL->Quandl)
#   Downloading https://files.pythonhosted.org/packages/97/18/c6557f63a6abde34707196fb2cad1c6dc0dbff25a200d5044922496668a4/cryptography-2.7-cp34-abi3-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 8.1MB/s
# Collecting asn1crypto>=0.21.0 (from cryptography>=2.3->pyOpenSSL->Quandl)
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 30.5MB/s
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.3->pyOpenSSL->Quandl) (1.12.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.3->pyOpenSSL->Quandl) (2.19)
# Building wheels for collected packages: inflection
#   Building wheel for inflection (setup.py) ... done
#   Created wheel for inflection: filename=inflection-0.3.1-cp36-none-any.whl size=6076 sha256=c76762458bcc6b1350652d05bc5f5e16c6e312eae2d18b24df9ea09a0a93ebf4
#   Stored in directory: /root/.cache/pip/wheels/9f/5a/d3/6fc3bf6516d2a3eb7e18f9f28b472110b59325f3f258fe9211
# Successfully built inflection
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: inflection, more-itertools, asn1crypto, cryptography, pyOpenSSL, ndg-httpsclient, Quandl
#   Found existing installation: more-itertools 7.2.0
#     Uninstalling more-itertools-7.2.0:
#       Successfully uninstalled more-itertools-7.2.0
# Successfully installed Quandl-3.4.8 asn1crypto-0.24.0 cryptography-2.7 inflection-0.3.1 more-itertools-5.0.0 ndg-httpsclient-0.5.1 pyOpenSSL-19.0.0

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import quandl
import pandas as pd
# import pandas_datareader.data as web
style.use('ggplot')
start_date = '2017-1-1'
end_date = '2019-1-31'
quandl.ApiConfig.api_key = 'gJbKvWPWeYcQz6zAqQB5'

# %%
import numpy as np
import seaborn as sns

# %% [markdown]
# # Loading the Data

# %%
# Download Microsoft stock data

stock_data=quandl.get('EOD/MSFT', start_date=start_date, end_date=end_date)

# %%
stock_data
# Out:
#               Open     High      Low  ...    Adj_Low  Adj_Close  Adj_Volume
# Date                                  ...
# 2017-01-03  62.790  62.8400  62.1250  ...  58.862106  59.293209  20694101.0
# 2017-01-04  62.480  62.7500  62.1200  ...  58.857369  59.027915  21339969.0
# 2017-01-05  62.190  62.6600  62.0300  ...  58.772096  59.027915  24875968.0
# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 250 entries, 2017-01-03 to 2017-12-28
# Data columns (total 6 columns):
# Open         250 non-null float64
# Close        250 non-null float64
# High         250 non-null float64
# Low          250 non-null float64
# Volume       250 non-null float64
# Adj_Close    250 non-null float64
# dtypes: float64(6)
# memory usage: 13.7 KB

# %%
stock_data.describe()
# Out:
#              Open       Close        High         Low        Volume   Adj_Close
# count  250.000000  250.000000  250.000000  250.000000  2.500000e+02  250.000000
# mean    71.899160   71.929800   72.321344   71.441966  2.245073e+07   68.981329
# std      6.972252    6.962381    7.032612    6.908122  8.185032e+06    7.107192
# min     62.190000   62.300000   62.660000   61.950000  7.425603e+06   59.027915
# 25%     65.397500   65.472500   65.750000   64.965000  1.789996e+07   62.348897
# 50%     70.865000   71.010000   71.495000   70.295000  2.089332e+07   68.067142
# 75%     75.082500   75.105000   75.465000   74.482500  2.466844e+07   72.375895
# max     87.120000   86.850000   87.499900   86.230000  7.106673e+07   84.117729

# %%
corr = stock_data.corr()
sns.heatmap(corr, annot=True)

# %%
df_test = stock_data[-20:]
print(df_test.shape)
df_test.head()
# Out:
# (20, 6)
#              Open  Close     High      Low      Volume  Adj_Close
# Date
# 2017-11-30  83.51  84.17  84.5200  83.3400  33054647.0  81.522041
# 2017-12-01  83.60  84.26  84.8100  83.2200  29532132.0  81.609210
# 2017-12-04  84.42  81.08  84.4299  80.7000  39094880.0  78.529251
# 2017-12-05  81.34  81.59  82.6800  80.9801  26152261.0  79.023207
# 2017-12-06  81.55  82.78  83.1400  81.4300  26162054.0  80.175770

# %%
df_train = stock_data[:-20]
print(df_train.shape)
# Out:
# (230, 6)

# %% [markdown]
# # Visualizing the data

# %%
# Plotting Train and Test data

def plot_train_val(train_data, val_data):
    fig = plt.figure(figsize=[10,8])
    ax = plt.subplot(111)
    ax.plot(train_data, label='Train')
    ax.plot(val_data, label='Valid')
    ax.legend()
    plt.show()

# %%
plot_train_val(df_train['Adj_Close'], df_test['Adj_Close'])
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Feature Engineering

# %%
window = 7                       # We will use the last 6 day data to make prediction

train_data = df_train['Adj_Close']
test_data = df_test['Adj_Close']

index = len(train_data) - window

# %%
index
# Out:
# 223

# %%
data = pd.DataFrame(np.zeros((index, window)))

for row in range(index):
  for col in range(window):
    data.iloc[row,col] = train_data[col+row]

# %%
data
# Out:
#              0          1          2  ...          4          5          6
# 0    59.293209  59.027915  59.027915  ...  59.350058  59.331108  59.871171
# 1    59.027915  59.027915  59.539553  ...  59.331108  59.871171  59.321633
# 2    59.027915  59.539553  59.350058  ...  59.871171  59.321633  59.406906
# 3    59.539553  59.350058  59.331108  ...  59.321633  59.406906  59.245835
# 4    59.350058  59.331108  59.871171  ...  59.406906  59.245835  59.217411
# 5    59.331108  59.871171  59.321633  ...  59.245835  59.217411  59.027915
# 6    59.871171  59.321633  59.406906  ...  59.217411  59.027915  59.444805
# 7    59.321633  59.406906  59.245835  ...  59.027915  59.444805  59.653251
# 210  80.157472  80.995859  81.082588  ...  81.207865  81.487327  81.034405
# 211  80.995859  81.082588  81.400597  ...  81.487327  81.034405  80.822400
# 212  81.082588  81.400597  81.207865  ...  81.034405  80.822400  80.880219
# 213  81.400597  81.207865  81.487327  ...  80.822400  80.880219  80.995859
# 214  81.207865  81.487327  81.034405  ...  80.880219  80.995859  80.369478
# 215  81.487327  81.034405  80.822400  ...  80.995859  80.369478  80.582557
# 216  81.034405  80.822400  80.880219  ...  80.369478  80.582557  79.807725
# 217  80.822400  80.880219  80.995859  ...  80.582557  79.807725  79.933635
# 218  80.880219  80.995859  80.369478  ...  79.807725  79.933635  81.086198
# 219  80.995859  80.369478  80.582557  ...  79.933635  81.086198  80.495388
# 220  80.369478  80.582557  79.807725  ...  81.086198  80.495388  80.640669
# 221  80.582557  79.807725  79.933635  ...  80.495388  80.640669  81.231479
# 222  79.807725  79.933635  81.086198  ...  80.640669  81.231479  82.209705
#
# [223 rows x 7 columns]

# %%
y_train = data.iloc[:,-1]
y_train.shape
# Out:
# (223,)

# %%
X_train = data.iloc[:,:-1]
X_train.shape
# Out:
# (223, 6)

# %% [markdown]
# Lets do the same steps for test data

# %%
index = len(test_data) - window

# %%
data = pd.DataFrame(np.zeros((index, window)))

for row in range(index):
  for col in range(window):
    data.iloc[row,col] = train_data[col+row]

# %%
y_test = data.iloc[:,-1]
y_test.shape
# Out:
# (13,)

# %%
X_test = data.iloc[:,:-1]
X_test.shape
# Out:
# (13, 6)

# %% [markdown]
# # Model **Building**

# %%
# Linear Regression
# XGBoost
# Keras LSTM

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred_lr)
print("Root Mean Squared Error: ", np.sqrt(mse))
# Out:
# Root Mean Squared Error:  0.5375293235138682

# %%
fig = plt.figure(figsize=[10,8])
ax = plt.subplot(111)
ax.plot(y_test.index, y_pred_lr, label='Predicted')
ax.plot(y_test, label='Test')
ax.legend()
plt.show()

# %% [markdown]
# # XGBoost Regression

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBRegressor(colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.07,
                 max_depth=3,
                 min_child_weight=1.5,
                 n_estimators=10000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)
xgb_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [15:53:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0,
#              importance_type='gain', learning_rate=0.07, max_delta_step=0,
#              max_depth=3, min_child_weight=1.5, missing=None,
#              n_estimators=10000, n_jobs=1, nthread=None, objective='reg:linear',
#              random_state=0, reg_alpha=0.75, reg_lambda=0.45,
#              scale_pos_weight=1, seed=42, silent=None, subsample=0.6,
#              verbosity=1)

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred_xgb)
print("Root Mean Squared Error: ", np.sqrt(mse))
# Out:
# Root Mean Squared Error:  0.06052751016032433

# %%
fig = plt.figure(figsize=[10,8])
ax = plt.subplot(111)
ax.plot(y_test.index, y_pred_xgb, label='Predicted')
ax.plot(y_test, label='Test')
ax.legend()
plt.show()

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)
y_pred_ridge = ridge_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred_ridge)
print("Root Mean Squared Error: ", np.sqrt(mse))
# Out:
# Root Mean Squared Error:  0.5369019721924813

# %%
fig = plt.figure(figsize=[10,8])
ax = plt.subplot(111)
ax.plot(y_test.index, y_pred_ridge, label='Predicted')
ax.plot(y_test, label='Test')
ax.legend()
plt.show()
